# %% [markdown]
# <h1>参考資料・文献</h1>

# %% [markdown]
# [*1]	Vison Transformer
# 「An Image is Worth 16x16 Words: Transformers for Image Recognition at Scale」	https://arxiv.org/abs/2010.11929
#
# [*2]	MLP-Mixer
# 「MLP-Mixer: An all-MLP Architecture for Vision」	https://arxiv.org/abs/2105.01601
#
# [*3]	「画像分類におけるCNNとVision Transformer の精度比較」
# https://ipsj.ixsq.nii.ac.jp/ej/?action=pages_view_main&active_action=repository_view_main_item_detail&item_id=213705&item_no=1&page_id=13&block_id=8
#
# [*4]	「細菌性肺炎との鑑別を要した新型コロナウイルス感染症の1 例」
# https://www.jstage.jst.go.jp/article/kansenshogakuzasshi/95/1/95_21/_article/-char/ja/
#
# [*5]	「Vision Transformer based COVID-19 Detection using Chest X-rays」	https://ieeexplore.ieee.org/abstract/document/9609375
#
# [*6]	MLP-Mixerモデル
# https://github.com/Benjamin-Etheredge/mlp-mixer-keras
#
# [*7]	胸部Ｘ線画像データセット
# https://www.kaggle.com/datasets/preetviradiya/covid19-radiography-dataset
#
# [*8]	【PyTorch】TorchEval を使って精度評価しよう	https://zenn.dev/a5chin/articles/torchevaluation
#
# [*9]	PyTorchによる転移学習の実装	https://venoda.hatenablog.com/entry/2020/10/14/071440
#
# [*10]	MLP-Mixerで独自データを高速学習してみる【ViT比較】	https://farml1.com/mlp_mixer/
#
# [*11]	独自データでViTモデルをつくる【Vision Transformer】	https://farml1.com/vit_2/
#
# [*12]	Very Deep Convolutional Networks for Large-Scale Image Recognition	https://arxiv.org/abs/1409.1556
