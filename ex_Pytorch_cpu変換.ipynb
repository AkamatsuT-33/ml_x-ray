# %% [markdown]
# ## cpu変換

# %%
model = torch.load('/content/drive/MyDrive/2022年度_3年/2022_人工知能応用/torch_model/VGG16_model_01.pth')

# %%
torch.save(model.to('cpu'),'/content/drive/MyDrive/2022年度_3年/2022_人工知能応用/torch_model/VGG16_model_cpu_01.pth' )

# %%
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 KB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 22.8 MB/s eta 0:00:00
# ...

# %%
import timm

# %%
model_v = torch.load('/content/drive/MyDrive/2022年度_3年/2022_人工知能応用/torch_model/vit_model_01.pth')

# %%
torch.save(model_v.to('cpu'),'/content/drive/MyDrive/2022年度_3年/2022_人工知能応用/torch_model/vit_model_cpu_01.pth' )

# %%
model_m = torch.load('/content/drive/MyDrive/2022年度_3年/2022_人工知能応用/torch_model/mlp-mixer_model_01.pth')

# %%
torch.save(model_m.to('cpu'),'/content/drive/MyDrive/2022年度_3年/2022_人工知能応用/torch_model/mlp-mixer_model_cpu_01.pth' )
